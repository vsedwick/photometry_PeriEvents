# %%
import config
import extraction.data_loader as DL
from pathlib import Path

# %% [markdown]
# #### **Loading configuration variables**
# We can navigate through the parameters in the config to double check that they are correct.
#
# ***params.dir*** will output directory information
#
# ***params.acq*** will output acquisition related variables
#
# ***params.behav*** will output behavior related variables
#
# ***params.plot*** will output plotting related variable (just z-score plot color for now)

# %%
#please provide configuration file directory
config_file = r"C:\Users\sedwi\Downloads\photometry_PeriEvents-master\photometry_PeriEvents-master\config.yaml"

params = config.AnalysisParameters(config.load_config(config_file))
#Directory related parameters
params.acq
# Out:
# <AcquisitionConfig(
#   silent_mode=False
#   full_trace=True
#   behav_fps=30
#   photo_fps=20
#   pre_s=5
#   post_s=10
#   roi=0
#   offset=0
#   crop_front=0
#   crop_end=0
# )>

# %% [markdown]
# #### Loading project files
# This program is meant to handle files in a 'batched' fashion however, you are able to upload individual files.
# Ideally, each of your trial files will be inside of their own folder labeled by trial id.
# In the batch execution, the package will accept the trial_id and the 'project_home' directory from the config variable.

# %%
dataloader = DL.TrialProcessor(trial_id = 3, config = params)
dataloader.photo_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 dataloader = DL.TrialProcessor(trial_id = 3, config = params)
# ----> 2 dataloader.photo_df
#
# AttributeError: 'TrialProcessor' object has no attribute 'photo_df'

# %%
# Out:
# <AcquisitionConfig(
#   silent_mode=False
#   full_trace=True
#   behav_fps=30
#   photo_fps=20
#   pre_s=5
#   post_s=10
#   roi=0
#   offset=0
#   crop_front=0
#   crop_end=0
# )>
